# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
ds=pd.read_csv("Cle@ned_data.csv")

# %%
ds
# Out:
#        Unnamed: 0 POSTED_BY  BHK_NO BHK_OR_RK    SQUARE_FT       CITY  Price
# 0               0     Owner       2       BHK  1300.236407  Bangalore   55.0
# 1               1    Dealer       2       BHK  1275.000000     Mysore   51.0
# 2               2     Owner       2       BHK   929.921143  Ghaziabad   62.5
# 3               3    Dealer       2       BHK   999.009247    Kolkata   60.5
# 4               4     Owner       3       BHK  1250.000000      Kochi   42.0
# ...           ...       ...     ...       ...          ...        ...    ...
# 12551       12551   Builder       3       BHK  1652.634861   Gulbarga   53.0
# 12552       12552    Dealer       3       BHK  1554.968123   Lalitpur  200.0
# 12553       12553    Dealer       1       BHK   752.049334     Mumbai  100.0
# 12554       12554     Owner       3       BHK  2500.000000       Agra   45.0
# 12555       12555    Dealer       2       BHK  1022.641509     Jaipur   27.1
#
# [12556 rows x 7 columns]

# %%
X=ds[["POSTED_BY","BHK_NO","BHK_OR_RK","SQUARE_FT","CITY"]]
Y=ds[["Price"]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
ohe=OneHotEncoder()
ohe.fit(X[["POSTED_BY","BHK_OR_RK","CITY"]])
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['Builder', 'Dealer', 'Owner'], dtype=object),
#  array(['BHK', 'RK'], dtype=object),
#  array(['Agra', 'Ahmednagar', 'Ajmer', 'Akola', 'Aligarh', 'Allahabad',
#         'Alwar', 'Ambala', 'Amravati', 'Amritsar', 'Amroha', 'Anand',
#         'Arrah', 'Asansol', 'Aurangabad', 'Avadi', 'Bahadurgarh',
#         'Bangalore', 'Barabanki', 'Bardhaman', 'Bareilly', 'Beed',
#         'Belgaum', 'Berhampur', 'Bhandara', 'Bharatpur', 'Bharuch',
#         'Bhavnagar', 'Bhilai', 'Bhimavaram', 'Bhiwadi', 'Bhiwani',
#         'Bhopal', 'Bhubaneswar', 'Bikaner', 'Bilaspur', 'Bokaro', 'Budha',
#         'Chak', 'Chandigarh', 'Chandrapur', 'Chennai', 'Chhindwara',
#         'Coimbatore', 'Cuttack', 'Dahod', 'Dalhousie', 'Dehradun',
#         'Deoghar', 'Dhanbad', 'Dharuhera', 'Dharwad', 'Dhule', 'Durg',
#         'Durgapur', 'Eluru', 'Ernakulam', 'Erode', 'Faridabad',
#         'Gadarwara', 'Gandhidham', 'Gandhinagar', 'Gaya', 'Ghaziabad',
# ...

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),["POSTED_BY","BHK_OR_RK","CITY"]),remainder="passthrough")

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,Y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Builder', 'Dealer', 'Owner'], dtype=object),
#                                                                             array(['BHK', 'RK'], dtype=object),
#                                                                             array(['Agra', 'Ahmednagar', 'Ajmer', 'Akola', 'Aligarh', 'Allahabad',
#        'Alwar', 'Ambala', 'Amravati', 'Amritsar', 'Amroha', 'Anand',
#        'Arrah', 'As...
#        'Telangana', 'Thanjavur', 'Thoothukudi', 'Thrissur', 'Tirunelveli',
#        'Tirupati', 'Udaipur', 'Udupi', 'Ujjain', 'Vadodara', 'Vakola',
#        'Valsad', 'Vapi', 'Varanasi', 'Vijayawada', 'Visakhapatnam',
#        'Vizianagaram', 'Wardha', 'Washim', 'akshaya', 'lekhraj',
# ...

# %%
y_pred=pipe.predict(X_test)
y_pred
# Out:
# array([[175.77342752],
#        [175.71263879],
#        [175.7479895 ],
#        ...,
#        [175.72868475],
#        [175.7206887 ],
#        [175.60062836]])

# %%
r2_score(Y_test,y_pred)
# Out:
# 0.00042537850299828595

# %%
scores=[]
for i in range(1000):
    X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,Y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(Y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 523

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_test,Y_test)
y_pred=pipe.predict(X_test)
r2_score(Y_test,y_pred)
# Out:
# 0.8436843899356958

# %%
data=[["Dealer","2","BHK","1250","Mysore"]]
columns=["POSTED_BY","BHK_NO","BHK_OR_RK","SQUARE_FT","CITY"]
myinput=pd.DataFrame(data=data,columns=columns)
result=pipe.predict(myinput)
round(result[0,0])
# Out:
# 65

# %%
import pickle as pkl
pkl.dump(pipe,open("HPP.pkl","wb+"))
