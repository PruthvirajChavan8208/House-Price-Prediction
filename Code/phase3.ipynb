# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
posted_by=input("Enter broker")
bhk_no=int(input("Enter the bhk no"))
bhk_rk=input("Enter the type of house")
sq_fit=int(input("Enter the sq fit of house"))
city=input("Enter the city")
# Out:
# Enter broker Owner
# Enter the bhk no 2
# Enter the type of house BHK
# Enter the sq fit of house 1250
# Enter the city Mysore

# %%
columns=["POSTED_BY","BHK_NO","BHK_OR_RK","SQUARE_FT","CITY"]
data=[[posted_by,bhk_no,bhk_rk,sq_fit,city]]
myinput=pd.DataFrame(data=data,columns=columns)
myinput
# Out:
#   POSTED_BY  BHK_NO BHK_OR_RK  SQUARE_FT    CITY
# 0     Owner       2       BHK       1250  Mysore

# %%
import pickle as pkl
model=pkl.load(open("HPP.pkl","rb+"))

# %%
result=model.predict(myinput)
round(result[0,0])
# Out:
# 55
