# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
ds=pd.read_csv("data.csv")

# %%
ds.head()
# Out:
#    Unnamed: 0 POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK  \
# 0           0     Owner                   0     0        2       BHK
# 1           1    Dealer                   0     0        2       BHK
# 2           2     Owner                   0     0        2       BHK
# 3           3     Owner                   0     1        2       BHK
# 4           4    Dealer                   1     0        2       BHK
#
#      SQUARE_FT  READY_TO_MOVE  RESALE                      ADDRESS  \
# 0  1300.236407              1       1        Ksfc Layout,Bangalore
# 1  1275.000000              1       1    Vishweshwara Nagar,Mysore
# 2   933.159722              1       1             Jigani,Bangalore
# 3   929.921143              1       1  Sector-1 Vaishali,Ghaziabad
# 4   999.009247              0       1             New Town,Kolkata
#
#    TARGET(PRICE_IN_LACS)
# 0                   55.0
# 1                   51.0
# 2                   43.0
# 3                   62.5
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29451 entries, 0 to 29450
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             29451 non-null  int64
#  1   POSTED_BY              29451 non-null  object
#  2   UNDER_CONSTRUCTION     29451 non-null  int64
#  3   RERA                   29451 non-null  int64
#  4   BHK_NO.                29451 non-null  int64
#  5   BHK_OR_RK              29451 non-null  object
#  6   SQUARE_FT              29451 non-null  float64
#  7   READY_TO_MOVE          29451 non-null  int64
#  8   RESALE                 29451 non-null  int64
#  9   ADDRESS                29451 non-null  object
#  10  TARGET(PRICE_IN_LACS)  29451 non-null  float64
# dtypes: float64(2), int64(6), object(3)
# memory usage: 2.5+ MB

# %%
ds.rename(columns={"ADDRESS":"CITY"},inplace=True)
ds.rename(columns={"BHK_NO.":"BHK_NO"},inplace=True)
ds.rename(columns={"TARGET(PRICE_IN_LACS)":"Price"},inplace=True)

# %%
#ds=ds.drop(columns=["UNDER_CONSTRUCTION","RERA","READY_TO_MOVE","RESALE","Unnamed: 0"]) #this is run so not shwoing there for it is comment

# %%
ds #All is good
# Out:
#       POSTED_BY  BHK_NO BHK_OR_RK    SQUARE_FT  \
# 0         Owner       2       BHK  1300.236407
# 1        Dealer       2       BHK  1275.000000
# 2         Owner       2       BHK   933.159722
# 3         Owner       2       BHK   929.921143
# 4        Dealer       2       BHK   999.009247
# ...         ...     ...       ...          ...
# 29446     Owner       3       BHK  2500.000000
# 29447     Owner       2       BHK   769.230769
# 29448    Dealer       2       BHK  1022.641509
# 29449     Owner       2       BHK   927.079009
# 29450    Dealer       2       BHK   896.774194
#
#                                     CITY  Price
# 0                  Ksfc Layout,Bangalore   55.0
# 1              Vishweshwara Nagar,Mysore   51.0
# 2                       Jigani,Bangalore   43.0
# 3            Sector-1 Vaishali,Ghaziabad   62.5
# 4                       New Town,Kolkata   60.5
# ...                                  ...    ...
# 29446               Shamshabad Road,Agra   45.0
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29451 entries, 0 to 29450
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   POSTED_BY  29451 non-null  object
#  1   BHK_NO     29451 non-null  int64
#  2   BHK_OR_RK  29451 non-null  object
#  3   SQUARE_FT  29451 non-null  float64
#  4   CITY       29451 non-null  object
#  5   Price      29451 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 1.3+ MB

# %%
#Quality check
# city : have large address
#city have nan value

# %%
ds["POSTED_BY"].unique()
ds["POSTED_BY"].isna().unique()
# Out:
# array([False])

# %%
ds["BHK_NO"].isna().unique() #first check unique then na
# Out:
# array([False])

# %%
ds["BHK_OR_RK"].isna().unique()
# Out:
# array([False])

# %%
ds["SQUARE_FT"].isna().unique()
# Out:
# array([False])

# %%
ds["CITY"].isna().unique()
# Out:
# array([False])

# %%
ds["Price"].isna().unique()
# Out:
# array([False])

# %%
ds["CITY"]=ds["CITY"].str.split().str.get(1).str.replace(","," ")

# %%
ds["CITY"]=ds["CITY"].str.split().str.get(1)

# %%
ds["CITY"].unique()
# Out:
# array(['Bangalore', 'Mysore', nan, 'Ghaziabad', 'Kolkata', 'Kochi',
#        'Siliguri', 'Noida', 'Raigad', 'Wardha', 'Mumbai', 'Nagpur',
#        'Mohali', 'Deoghar', 'Jaipur', 'Lalitpur', 'Maharashtra', 'Kanpur',
#        'Gurgaon', 'Vadodara', 'Indore', 'Valsad', 'Surat', 'Amravati',
#        'Guwahati', 'Chandigarh', 'Shimla', 'Gwalior', 'Bhopal', 'Vapi',
#        'Rajkot', 'Raipur', 'Pune', 'Berhampur', 'Faridabad', 'Chennai',
#        'Latur', 'Panchkula', 'Bhubaneswar', 'Sonipat', 'Vijayawada',
#        'Jabalpur', 'Visakhapatnam', 'Hosur', 'Vizianagaram', 'Morbi',
#        'Hubli', 'Karnal', 'Pondicherry', 'Patna', 'Bilaspur', 'Allahabad',
#        'Amritsar', 'Patiala', 'Lucknow', 'Ernakulam', 'Varanasi',
#        'Bharuch', 'Bhilai', 'Secunderabad', 'Jalgaon', 'Jamshedpur',
#        'Mangalore', 'Aurangabad', 'Neemrana', 'Agra', 'ranchi',
#        'Ludhiana', 'Goa', 'Bahadurgarh', 'Palghar', 'Meerut',
#        'Coimbatore', 'next', 'Dhule', 'Dehradun', 'Anand', 'Bhiwadi',
# ...

# %%
ds=ds[~ds["CITY"].isna()]

# %%
ds=ds.reset_index(drop=True)

# %%
ds
# Out:
#       POSTED_BY  BHK_NO BHK_OR_RK    SQUARE_FT       CITY  Price
# 0         Owner       2       BHK  1300.236407  Bangalore   55.0
# 1        Dealer       2       BHK  1275.000000     Mysore   51.0
# 2         Owner       2       BHK   929.921143  Ghaziabad   62.5
# 3        Dealer       2       BHK   999.009247    Kolkata   60.5
# 4         Owner       3       BHK  1250.000000      Kochi   42.0
# ...         ...     ...       ...          ...        ...    ...
# 12551   Builder       3       BHK  1652.634861   Gulbarga   53.0
# 12552    Dealer       3       BHK  1554.968123   Lalitpur  200.0
# 12553    Dealer       1       BHK   752.049334     Mumbai  100.0
# 12554     Owner       3       BHK  2500.000000       Agra   45.0
# 12555    Dealer       2       BHK  1022.641509     Jaipur   27.1
#
# [12556 rows x 6 columns]

# %%
ds.to_csv("Cle@ned_data.csv")
